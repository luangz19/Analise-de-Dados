# %% [markdown]
# <a href="https://colab.research.google.com/github/luangz19/Analise-de-Dados/blob/main/E-commerce-Marketing-and-Sales-Revenue/2_Distribui%C3%A7%C3%A3o_de_Frequ%C3%AAncias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Importação dos Dados

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("amineipad/e-commerce-marketing-and-sales-revenue-prediction")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'e-commerce-marketing-and-sales-revenue-prediction' dataset.
# Path to dataset files: /kaggle/input/e-commerce-marketing-and-sales-revenue-prediction

# %%
import os

os.listdir(path)
# Out:
# ['train.csv', 'test.csv']

# %%
import pandas as pd
import seaborn as sns

# %%
data_train = pd.read_csv(path + '/train.csv')
data_test = pd.read_csv(path + '/train.csv')

# %% [markdown]
# # 2 - Resumo de Dados

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       18000 non-null  int64
#  1   date                     18000 non-null  object
#  2   region                   18000 non-null  object
#  3   channel                  18000 non-null  object
#  4   product_category         18000 non-null  object
#  5   customer_segment         18000 non-null  object
#  6   ad_spend                 17342 non-null  float64
#  7   price                    18000 non-null  float64
#  8   discount_rate            17245 non-null  float64
#  9   market_reach             17314 non-null  float64
#  10  impressions              18000 non-null  int64
#  11  click_through_rate       17287 non-null  float64
#  12  competition_index        17293 non-null  float64
#  13  seasonality_index        18000 non-null  float64
#  14  campaign_duration_days   16487 non-null  float64
#  15  customer_lifetime_value  17257 non-null  float64
#  16  sales_revenue            18000 non-null  float64
# dtypes: float64(10), int64(2), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 2.1 - Leitura das primeiras linhas

# %%
data_train.head()
# Out:
#    id                 date region       channel product_category  \
# 0   1  2011-12-05 11:31:00   Nort        Search          General
# 1   2  2011-04-27 14:01:00  North  Social Media          General
# 2   3  2010-11-09 15:20:00  North     Affiliate          General
# 3   4  2010-10-03 15:24:00  North     Affiliate          Storage
# 4   5  2011-10-14 09:28:00  North        Search         Lighting
#
#   customer_segment  ad_spend  price  discount_rate  market_reach  impressions  \
# 0         Standard      9.00   0.75         0.2782          32.0          817
# 1          Premium      3.35   3.35         0.0912          61.0         2289
# 2           Budget      2.55   2.55         0.1997         461.0        14697
# 3          Premium      2.95   2.95         0.4767         744.0        17578
# 4          Premium     15.00   1.25         0.3536         226.0         6280
#
#    click_through_rate  competition_index  seasonality_index  \
# 0              0.0010               3.34           1.000000
# 1              0.0640               4.44           0.366025
# 2              0.1508               3.31           0.366025
# 3              0.1965               2.87          -0.366025
# 4              0.0200               7.40          -0.366025
#
#    campaign_duration_days  customer_lifetime_value  sales_revenue
# 0                    30.0                   816.49     119.767811
# 1                    90.0                  1723.16     119.404661
# 2                    21.0                  1151.74     132.009747
# 3                    90.0                  3585.85     154.511756
# 4                    90.0                   502.28     128.059924

# %% [markdown]
# ## 2.2 - Nome das colunas

# %%
data_train.columns
# Out:
# Index(['id', 'date', 'region', 'channel', 'product_category',
#        'customer_segment', 'ad_spend', 'price', 'discount_rate',
#        'market_reach', 'impressions', 'click_through_rate',
#        'competition_index', 'seasonality_index', 'campaign_duration_days',
#        'customer_lifetime_value', 'sales_revenue'],
#       dtype='object')

# %%
for i in data_train.columns:
  if data_train[i].dtype == "object":
    print(f"{i}:", data_train[i].unique(), "\n")
# Out:
# date: ['2011-12-05 11:31:00' '2011-04-27 14:01:00' '2010-11-09 15:20:00' ...
#  '2011-01-13 13:21:00' '2010-11-09 14:11:00' '2011-11-20 12:11:00']
#
# region: ['Nort' 'North' 'north' 'NORTH' 'Central' 'Norht' 'north ' 'East' 'West'
#  'South']
#
# channel: ['Search' 'Social Media' 'Affiliate' 'Email' 'TV' 'Influencer'
#  'Social_Media' 'Socail Media' 'social Media' 'SocialMedia' 'social media']
#
# product_category: ['General' 'Storage' 'Lighting' 'Stationery' 'Kitchen' 'Seasonal']
#
# customer_segment: ['Standard' 'Premium' 'Budget']

# %%
print(data_train["region"].value_counts())
# Out:
# region
# North      16305
# East         374
# Norht        248
# north        242
# NORTH        209
# Nort         200
# north        199
# Central      109
# West          77
# South         37
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3 - Padronizando os nomes da coluna region

# %%
def cap(x):
  x = x.capitalize()
  if x == "Norht" or x == "Nort" or x == "North ":
    x = "North"
  return x

data_train["region"] = data_train["region"].apply(cap)
data_train["region"].value_counts()
# Out:
# region
# North      17403
# East         374
# Central      109
# West          77
# South         37
# Name: count, dtype: int64

# %%
print(data_train["channel"].value_counts())
# Out:
# channel
# Social Media    4246
# Email           3625
# Search          3600
# Affiliate       2632
# TV              1848
# Influencer      1806
# social Media      55
# SocialMedia       50
# Social_Media      48
# Socail Media      45
# social media      45
# Name: count, dtype: int64

# %% [markdown]
# ## 2.4 Padronizando os nomes da coluna channel

# %%
def cap2(x):
  palavra = ""
  x = x.capitalize()
  for i in x:
    palavra += i
    if palavra == "Soc":
      x = "Social Media"
      break
      return x
  return x

# %%
data_train["channel"] = data_train["channel"].apply(cap2)
data_train["channel"].value_counts()
# Out:
# channel
# Social Media    4489
# Email           3625
# Search          3600
# Affiliate       2632
# Tv              1848
# Influencer      1806
# Name: count, dtype: int64

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       18000 non-null  int64
#  1   date                     18000 non-null  object
#  2   region                   18000 non-null  object
#  3   channel                  18000 non-null  object
#  4   product_category         18000 non-null  object
#  5   customer_segment         18000 non-null  object
#  6   ad_spend                 17342 non-null  float64
#  7   price                    18000 non-null  float64
#  8   discount_rate            17245 non-null  float64
#  9   market_reach             17314 non-null  float64
#  10  impressions              18000 non-null  int64
#  11  click_through_rate       17287 non-null  float64
#  12  competition_index        17293 non-null  float64
#  13  seasonality_index        18000 non-null  float64
#  14  campaign_duration_days   16487 non-null  float64
#  15  customer_lifetime_value  17257 non-null  float64
#  16  sales_revenue            18000 non-null  float64
# dtypes: float64(10), int64(2), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# # 3 - Tipos de dados

# %% [markdown]
# ## 3.1 - Dados Qualitativos

# %%
dados_qualitativos = [i for i in data_train.columns if data_train[i].dtype == "object"]
dados_qualitativos
# Out:
# ['date', 'region', 'channel', 'product_category', 'customer_segment']

# %% [markdown]
# ### 3.1.1 Dados Qualitativos Nominal

# %%
dados_qualitativos[1:4]
# Out:
# ['region', 'channel', 'product_category']

# %% [markdown]
# ### 3.1.2 Dados Qualitativos Ordinal

# %%
dados_qualitativos[4:]
# Out:
# ['customer_segment']

# %% [markdown]
# ## 3.2 - Dados Quantitativos

# %%
dados_quantitativos = [i for i in data_train.columns if data_train[i].dtype != "object"]
dados_quantitativos
# Out:
# ['id',
#  'ad_spend',
#  'price',
#  'discount_rate',
#  'market_reach',
#  'impressions',
#  'click_through_rate',
#  'competition_index',
#  'seasonality_index',
#  'campaign_duration_days',
#  'customer_lifetime_value',
#  'sales_revenue']

# %% [markdown]
# ### 3.2.1 Dados Discretos

# %%
for i in dados_quantitativos[1:]:
    if data_train[i].dtype == "int64":
      print(i)
# Out:
# impressions

# %% [markdown]
# ### 3.2.1 Dados Contínuos

# %%
for i in dados_quantitativos[1:]:
    if data_train[i].dtype == "float64":
      print(i)
# Out:
# ad_spend
# price
# discount_rate
# market_reach
# click_through_rate
# competition_index
# seasonality_index
# campaign_duration_days
# customer_lifetime_value
# sales_revenue

# %% [markdown]
# # 4 - Distribuição de Frequências

# %% [markdown]
# ## 4.1 - Distribuição de Frequências para os dados qualitativos

# %%
for i in dados_qualitativos[1:]:
  index, valor = data_train[i].value_counts().index, data_train[i].value_counts().values
  dic = {i:index, "Frequência":valor, "Proporção":(valor/(sum(valor))).round(3), "Porcentagem %":(valor/(sum(valor))*100).round(2)}
  print(pd.DataFrame(dic), "\n")
# Out:
#     region  Frequência  Proporção  Porcentagem %
# 0    North       17403      0.967          96.68
# 1     East         374      0.021           2.08
# 2  Central         109      0.006           0.61
# 3     West          77      0.004           0.43
# 4    South          37      0.002           0.21
#
#         channel  Frequência  Proporção  Porcentagem %
# 0  Social Media        4489      0.249          24.94
# 1         Email        3625      0.201          20.14
# 2        Search        3600      0.200          20.00
# 3     Affiliate        2632      0.146          14.62
# 4            Tv        1848      0.103          10.27
# 5    Influencer        1806      0.100          10.03
#
#   product_category  Frequência  Proporção  Porcentagem %
# 0          General        8984      0.499          49.91
# 1          Storage        3775      0.210          20.97
# 2         Seasonal        1878      0.104          10.43
# 3       Stationery        1477      0.082           8.21
# 4          Kitchen        1042      0.058           5.79
# 5         Lighting         844      0.047           4.69
#
#   customer_segment  Frequência  Proporção  Porcentagem %
# 0          Premium       14445      0.802          80.25
# 1         Standard        2764      0.154          15.36
# 2           Budget         791      0.044           4.39

# %% [markdown]
# ## 4.1 - Distribuição de Frequências para os dados qualitativos

# %%
for i in dados_quantitativos[1:]:
  index, valor = data_train[i].value_counts(bins=6).index, data_train[i].value_counts(bins=6).values
  dic = {i:index, "Frequência":valor, "Proporção":(valor/(sum(valor))).round(3), "Porcentagem %":(valor/(sum(valor))*100).round(2)}
  print(pd.DataFrame(dic), "\n")
# Out:
#                ad_spend  Frequência  Proporção  Porcentagem %
# 0     (-4.075, 709.233]       17026      0.982          98.18
# 1   (709.233, 1418.287]         184      0.011           1.06
# 2   (1418.287, 2127.34]         131      0.008           0.76
# 3    (3545.447, 4254.5]           1      0.000           0.01
# 4   (2127.34, 2836.393]           0      0.000           0.00
# 5  (2836.393, 3545.447]           0      0.000           0.00
#
#               price  Frequência  Proporção  Porcentagem %
# 0    (-0.256, 49.2]       17695      0.983          98.31
# 1   (98.36, 147.52]          96      0.005           0.53
# 2  (147.52, 196.68]          82      0.005           0.46
# 3  (196.68, 245.84]          81      0.004           0.45
# 4     (49.2, 98.36]          26      0.001           0.14
# 5   (245.84, 295.0]          20      0.001           0.11
#
#     discount_rate  Frequência  Proporção  Porcentagem %
# 0      (0.1, 0.2]        4572      0.265          26.51
# 1  (-0.0014, 0.1]        3867      0.224          22.42
# 2      (0.2, 0.3]        3759      0.218          21.80
# 3      (0.3, 0.4]        2445      0.142          14.18
# 4      (0.4, 0.5]        1486      0.086           8.62
# 5      (0.5, 0.6]        1116      0.065           6.47
#
#           market_reach  Frequência  Proporção  Porcentagem %
# 0     (-0.49, 249.167]        7920      0.457          45.74
# 1   (249.167, 497.333]        6044      0.349          34.91
# 2     (497.333, 745.5]        2388      0.138          13.79
# 3     (745.5, 993.667]         637      0.037           3.68
# 4   (1241.833, 1490.0]         172      0.010           0.99
# 5  (993.667, 1241.833]         153      0.009           0.88
#
#                 impressions  Frequência  Proporção  Porcentagem %
# 0     (3355.167, 37481.333]       11730      0.652          65.17
# 1    (-30975.758, 3355.167]        6121      0.340          34.01
# 2      (37481.333, 71607.5]         134      0.007           0.74
# 3     (71607.5, 105733.667]          14      0.001           0.08
# 4    (139859.833, 173986.0]           1      0.000           0.01
# 5  (105733.667, 139859.833]           0      0.000           0.00
#
#     click_through_rate  Frequência  Proporção  Porcentagem %
# 0  (-0.001436, 0.0726]       12313      0.712          71.23
# 1      (0.0726, 0.145]        3867      0.224          22.37
# 2       (0.145, 0.218]         921      0.053           5.33
# 3        (0.218, 0.29]         154      0.009           0.89
# 4        (0.29, 0.363]          29      0.002           0.17
# 5       (0.363, 0.436]           3      0.000           0.02
#
#   competition_index  Frequência  Proporção  Porcentagem %
# 0    (3.243, 4.845]        4728      0.273          27.34
# 1    (1.642, 3.243]        4466      0.258          25.83
# 2    (4.845, 6.447]        3601      0.208          20.82
# 3   (0.0294, 1.642]        2256      0.130          13.05
# 4    (6.447, 8.048]        1784      0.103          10.32
# 5     (8.048, 9.65]         458      0.026           2.65
#
#                seasonality_index  Frequência  Proporção  Porcentagem %
# 0  (-1.3699999999999999, -0.911]        5375      0.299          29.86
# 1                 (0.911, 1.366]        5158      0.287          28.66
# 2                   (0.0, 0.455]        3923      0.218          21.79
# 3                  (-0.455, 0.0]        3544      0.197          19.69
# 4               (-0.911, -0.455]           0      0.000           0.00
# 5                 (0.455, 0.911]           0      0.000           0.00
#
#          campaign_duration_days  Frequência  Proporção  Porcentagem %
# 0              (20.833, 34.667]        7063      0.428          42.84
# 1  (6.9159999999999995, 20.833]        4740      0.287          28.75
# 2                (48.5, 62.333]        2357      0.143          14.30
# 3                (76.167, 90.0]        2327      0.141          14.11
# 4                (34.667, 48.5]           0      0.000           0.00
# 5              (62.333, 76.167]           0      0.000           0.00
#
#    customer_lifetime_value  Frequência  Proporção  Porcentagem %
# 0    (-542.679, 90538.475]       16843      0.976          97.60
# 1    (90538.475, 181076.4]         222      0.013           1.29
# 2   (181076.4, 271614.325]         109      0.006           0.63
# 3  (271614.325, 362152.25]          49      0.003           0.28
# 4   (452690.175, 543228.1]          18      0.001           0.10
# 5  (362152.25, 452690.175]          16      0.001           0.09
#
#         sales_revenue  Frequência  Proporção  Porcentagem %
# 0  (114.053, 228.107]       10174      0.565          56.52
# 1   (-0.685, 114.053]        6656      0.370          36.98
# 2   (228.107, 342.16]        1086      0.060           6.03
# 3   (342.16, 456.214]          78      0.004           0.43
# 4  (456.214, 570.267]           5      0.000           0.03
# 5   (570.267, 684.32]           1      0.000           0.01
